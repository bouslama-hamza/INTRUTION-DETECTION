# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.set_theme(style="darkgrid")

# %%
# Plot
from pandas.plotting import andrews_curves

plt.figure(figsize=(8,4.5), dpi= 80 , frameon = False )
andrews_curves(df, 'day', colormap='Set1')

# Lighten borders
plt.gca().spines["top"].set_alpha(0)
plt.gca().spines["bottom"].set_alpha(.3)
plt.gca().spines["right"].set_alpha(0)
plt.gca().spines["left"].set_alpha(.3)

plt.xlim(-3,3)
plt.grid(alpha=0.3)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.axis('off')
plt.savefig("plot.png" , transparent=True)

# %%
# numbers and dataframe processing
import pandas as pd
import numpy as np

# graphing
import plotly.offline as py
import plotly.graph_objs as go
py.init_notebook_mode()
import cufflinks as cf

# wrappers that help loading data
import quandl
quandl.ApiConfig.api_key = 'your_quandl_api_key'
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-28-e5cbff3dc630> in <module>
#       4
#       5 # graphing
# ----> 6 import plotly.offline as py
#       7 import plotly.graph_objs as go
#       8 py.init_notebook_mode()
#
# ModuleNotFoundError: No module named 'plotly'

# %%
df_normal = pd.read_csv('Not_Intrue_Detection.csv')
df_intrue = pd.read_csv('Intrue_Detection.csv')

# %%
df_normal
# Out:
#               day  Raspi One  Raspi Two  Raspi Three
# 0  26 / 02 / 2022       1250       1350          560
# 1  27 / 02 / 2022       1400       1620          170
# 2  28 / 02 / 2022        240        620          310
# 3  01 / 03 / 2022        170        420          722
# 4  02 / 03 / 2022        940       1450         1200

# %%
df_intrue
# Out:
#               day  Raspi One  Raspi Two  Raspi Three
# 0  26 / 02 / 2022         50        152          512
# 1  27 / 02 / 2022        120        420          561
# 2  28 / 02 / 2022        540        620          562
# 3  01 / 03 / 2022        770        120          563
# 4  02 / 03 / 2022        990        142          574

# %%
df_normal['Raspi One'][0]
# Out:
# 1250

# %%
som_normal = df_normal['Raspi One'][0] + df_normal['Raspi Two'][0] +  df_normal['Raspi Three'][0]
som_intrue = df_intrue['Raspi One'][0] + df_intrue['Raspi Two'][0] +  df_intrue['Raspi Three'][0]

# %%
som_total = som_normal + som_intrue

# %%
import matplotlib.pyplot as plt
fig = plt.figure(frameon=False)
fig.set_size_inches(10,5)
ax = plt.Axes(fig, [0., 0., 1., 1.])
ax.set_axis_off()
fig.add_axes(ax)
fig.savefig('test.png')

# %%
df
# Out:
#              date  Students Detection  Intrusion Detection
# 0  10 / 03 / 2022                1500                  150
# 1  11 / 03 / 2022                1300                  400
# 2  12 / 03 / 2022                1400                  500
# 3  13 / 03 / 2022                1200                  200
# 4  14 / 03 / 2022                1000                  100
# 5  15 / 03 / 2022                1300                  300
# 6  16 / 03 / 2022                1200                  300
# 7  17 / 03 / 2022                1400                  800

# %%
df['date'][0]
# Out:
# '14 / 03 / 2022'

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,4.5), dpi= 80 , frameon = False)
plt.area(df['date'] , df['Students Detection'], c= 'g')
plt.area(df['date'] , df['Intrusion Detection'], c= 'r')
plt.savefig("plot.png" , transparent=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-370a96d39211> in <module>
#       1 import matplotlib.pyplot as plt
#       2 plt.figure(figsize=(8,4.5), dpi= 80 , frameon = False)
# ----> 3 plt.area(df['date'] , df['Students Detection'], c= 'g')
#       4 plt.area(df['date'] , df['Intrusion Detection'], c= 'r')
#       5 plt.savefig("plot.png" , transparent=True)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'area'

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(9,5), dpi= 80 , frameon = False)
plt.style.use('seaborn-darkgrid')
plt.fill_between(df['date'][len(df['Students Detection'])-1:len(df['Students Detection'])-6:-1], df['Students Detection'][len(df['Students Detection'])-1:len(df['Students Detection'])-6:-1], color="skyblue", alpha=0.3)
plt.fill_between(df['date'][len(df['Students Detection'])-1:len(df['Students Detection'])-6:-1], df['Intrusion Detection'][len(df['Students Detection'])-1:len(df['Students Detection'])-6:-1], color="lightcoral", alpha=0.3)
plt.plot(df['date'][len(df['Students Detection'])-1:len(df['Students Detection'])-6:-1], df['Students Detection'][len(df['Students Detection'])-1:len(df['Students Detection'])-6:-1], marker ='o',color="skyblue" , label ='Student Detected')
plt.plot(df['date'][len(df['Students Detection'])-1:len(df['Students Detection'])-6:-1], df['Intrusion Detection'][len(df['Students Detection'])-1:len(df['Students Detection'])-6:-1],marker ='o', color="lightcoral" , label = 'Intrusion Detected')
plt.gca().get_yaxis().set_visible(False)
plt.savefig("plot.png" , transparent=True)

# %%
labels  = ['Students' ,'Intrusion']
test = [df['Students Detection'][len(df['Students Detection'])-1] , df['Intrusion Detection'][len(df['Students Detection'])-1]]
plt.figure(figsize=(4.5,5), dpi= 80 , frameon = False)
plt.pie(test ,  labels = labels)
plt.savefig("pie.png" , transparent=True)

# %%
df['Students Detection'][len(df['Students Detection'])-1]
# Out:
# 1400

# %%
df['Intrusion Detection'][len(df['Students Detection'])-1]
# Out:
# 800

# %%
df['Intrusion Detection'][0]+df['Students Detection'][0]
# Out:
# 1650

# %%
df['Students Detection'][0] /  (df['Intrusion Detection'][0]+df['Students Detection'][0]) *100
# Out:
# 90.9090909090909

# %%
from csv import writer

# %%
me = ['17 / 03 / 2022' , 1400 , 800]

# %%
with open("Intrue_Detection.csv" , 'a') as f:
    object_write = writer(f)
    object_write.writerow(me)
    f.close()

# %%
df = pd.read_csv('Intrue_Detection.csv')

# %%
len(df['Students Detection'])
# Out:
# 7

# %%
df['Students Detection'][len(df['Students Detection'])-1]
# Out:
# 1300

# %%
df['Students Detection'][len(df['Students Detection'])-1:len(df['Students Detection'])-6:-1]
# Out:
# 7    1400
# 6    1200
# 5    1300
# 4    1000
# 3    1200
# Name: Students Detection, dtype: int64
